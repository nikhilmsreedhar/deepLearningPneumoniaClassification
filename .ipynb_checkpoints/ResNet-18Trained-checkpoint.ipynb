# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import matplotlib.image as mpimg
import os
import cv2
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from glob import glob
import glob
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.preprocessing import image
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Input, Dropout, ZeroPadding2D, Conv2D, BatchNormalization, Activation, Add, Flatten, Dense, AveragePooling2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
trainLabels = "chest_xray/train/"
testLabels = "chest_xray/test/"
valLabels = "chest_xray/val/"

trainNormal = glob.glob(trainLabels+"NORMAL/*.jpeg")
trainPneumonia = glob.glob(trainLabels+"PNEUMONIA/*.jpeg")
valNormal = glob.glob(valLabels+"NORMAL/*.jpeg")
valPneumonia = glob.glob(valLabels+"PNEUMONIA/*.jpeg")
testNormal = glob.glob(testLabels+"NORMAL/*.jpeg")
testPneumonia = glob.glob(testLabels+"PNEUMONIA/*.jpeg")

sns.barplot(x=["Normal","Pneumonia"],y=[len(trainNormal),len(trainPneumonia)])
# Out:
# <AxesSubplot:>

# %%
print('Pneumonia x-ray images in training set = ', len(trainPneumonia))
print('Normal x-ray images in training set = ', len(trainNormal))
print('Pneumonia x-ray images in validation set = ', len(valPneumonia))
print('Normal x-ray images in validation set = ', len(valNormal))
print('Pneumonia x-ray images in test set = ', len(testPneumonia))
print('Normal x-ray images in test set = ', len(testNormal))
# Out:
# Pneumonia x-ray images in training set =  3875
# Normal x-ray images in training set =  1341
# Pneumonia x-ray images in validation set =  8
# Normal x-ray images in validation set =  8
# Pneumonia x-ray images in test set =  390
# Normal x-ray images in test set =  234

# %%
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    img = cv2.imread(trainPneumonia[i])
    img = cv2.resize(img, (200,200))
    ax.imshow(img)
    ax.set_title("Pneumonia")
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    img = cv2.imread(trainNormal[i])
    img = cv2.resize(img, (200,200))
    ax.imshow(img)
    ax.set_title("Normal")
# fig.tight_layout()    
plt.show()

# %%
training = ImageDataGenerator(preprocessing_function = preprocess_input)
validation = ImageDataGenerator(preprocessing_function = preprocess_input)
testing = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
training_dataset = training.flow_from_directory('chest_xray/train/',
                                            target_size = (224,224), 
                                            batch_size = 16,
                                            class_mode = 'binary')

validation_dataset = validation.flow_from_directory('chest_xray/val/',
                                            target_size = (224,224), 
                                            batch_size = 16,
                                            class_mode = 'binary')

testing_dataset = testing.flow_from_directory('chest_xray/test/',
                                            target_size = (224,224), 
                                            batch_size = 16,
                                            class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
training_dataset.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
training_dataset.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
# callback = ReduceLROnPlateau(monitor='val_loss', patience = 2, cooldown=0, verbose=1, factor=0.6, min_lr=0.000001)
resmodel = ResNet50(weights = None, include_top=True, input_shape= (224,224,3), pooling = 'avg')
# for layers in resmodel.layers:
#     layers.trainable = True
last_layer=resmodel.get_layer('conv3_block3_1_relu')#conv2_block1_out
last_output = last_layer.output

# x = AveragePooling2D((2,2), padding = 'same')(last_output)

x=tf.keras.layers.Flatten()(last_output)
# # x=tf.keras.layers.Dense(1024,activation='relu')(x)
# x=tf.keras.layers.Dropout(0.2)(x)
# x=tf.keras.layers.Dense(256,activation='relu')(x)
x=tf.keras.layers.Dropout(0.5)(x) ####### BEST RESULTS WITH ONE 0.5 DROPOUT LAYER AND EVERYTHING ELSE THE SAME ###########
x=tf.keras.layers.Dense(1,activation='sigmoid')(x)

modelres=tf.keras.Model(resmodel.input,x)

modelres.compile(loss = 'binary_crossentropy', 
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005), #0.0001 and no 256 dense layer led to low loss
             metrics = ['accuracy']) #lr of 0.00005 with dense layers led to good training but same val accuracy
modelres.summary()
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_27[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  flatten_25 (Flatten)           (None, 100352)       0           ['conv3_block3_1_relu[0][0]']
#
#  dropout_28 (Dropout)           (None, 100352)       0           ['flatten_25[0][0]']
#
#  dense_32 (Dense)               (None, 1)            100353      ['dropout_28[0][0]']
#
# ==================================================================================================
# Total params: 1,061,889
# Trainable params: 1,054,593
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
callback1 = ReduceLROnPlateau(monitor='val_loss', patience = 3, cooldown=0, verbose=1, factor=0.6, min_lr=0.00001)
callback2 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=9, restore_best_weights = True)
history = modelres.fit(training_dataset, validation_data = validation_dataset, epochs = 30, steps_per_epoch = 2, callbacks = [callback1, callback2])
# Out:
# Epoch 1/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.5042 - accuracy: 0.8125 - val_loss: 0.5278 - val_accuracy: 0.6875 - lr: 3.0000e-05
# Epoch 2/30
# 2/2 [==============================] - 5s 3s/step - loss: 0.3039 - accuracy: 0.8438 - val_loss: 0.4903 - val_accuracy: 0.8125 - lr: 3.0000e-05
# Epoch 3/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.4024 - accuracy: 0.8438 - val_loss: 0.4635 - val_accuracy: 0.8125 - lr: 3.0000e-05
# Epoch 4/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.3036 - accuracy: 0.8750 - val_loss: 0.4433 - val_accuracy: 0.8750 - lr: 3.0000e-05
# Epoch 5/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.1567 - accuracy: 0.9375 - val_loss: 0.4353 - val_accuracy: 0.8750 - lr: 3.0000e-05
# Epoch 6/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.3967 - accuracy: 0.8438 - val_loss: 0.4336 - val_accuracy: 0.8750 - lr: 3.0000e-05
# Epoch 7/30
# 2/2 [==============================] - 7s 4s/step - loss: 0.3890 - accuracy: 0.7812 - val_loss: 0.4320 - val_accuracy: 0.8750 - lr: 3.0000e-05
# Epoch 8/30
# 2/2 [==============================] - 7s 4s/step - loss: 0.3251 - accuracy: 0.8750 - val_loss: 0.4332 - val_accuracy: 0.8750 - lr: 3.0000e-05
# Epoch 9/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.3301 - accuracy: 0.9062 - val_loss: 0.4432 - val_accuracy: 0.9375 - lr: 3.0000e-05
# Epoch 10/30
# 2/2 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.7812
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.7999999545281754e-05.
# 2/2 [==============================] - 6s 3s/step - loss: 0.5006 - accuracy: 0.7812 - val_loss: 0.4471 - val_accuracy: 0.9375 - lr: 3.0000e-05
# Epoch 11/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.2469 - accuracy: 0.8750 - val_loss: 0.4515 - val_accuracy: 0.9375 - lr: 1.8000e-05
# Epoch 12/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.2337 - accuracy: 0.8438 - val_loss: 0.4554 - val_accuracy: 0.9375 - lr: 1.8000e-05
# Epoch 13/30
# 2/2 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8438
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0799999290611594e-05.
# 2/2 [==============================] - 7s 4s/step - loss: 0.2862 - accuracy: 0.8438 - val_loss: 0.4655 - val_accuracy: 0.8125 - lr: 1.8000e-05
# Epoch 14/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.2717 - accuracy: 0.8438 - val_loss: 0.4732 - val_accuracy: 0.8125 - lr: 1.0800e-05

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']



loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
norm_path = 'chest_xray/test/NORMAL'
arr = os.listdir(norm_path)
# print(arr)
# random.shuffle(arr)
for i in arr[:10]:
#     print(i)
    img = cv2.imread(norm_path+'/'+i)
    img = cv2.resize(img, (224,224))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis = 0)
    images = np.vstack([X])
    
    val = modelres.predict(images)
    print(val)
    if val < 0.1:
        print("Normal")
    else:
        print("Pneumonia")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# [[0.05705529]]
# Normal
# 1/1 [==============================] - 0s 60ms/step
# [[0.084094]]
# Normal
# 1/1 [==============================] - 0s 59ms/step
# [[0.14214827]]
# Pneumonia
# 1/1 [==============================] - 0s 59ms/step
# [[0.19670485]]
# Pneumonia
# 1/1 [==============================] - 0s 63ms/step
# [[0.15620355]]
# Pneumonia
# 1/1 [==============================] - 0s 71ms/step
# [[0.10056085]]
# Pneumonia
# 1/1 [==============================] - 0s 62ms/step
# [[0.04340436]]
# Normal
# 1/1 [==============================] - 0s 62ms/step
# [[0.12480436]]
# Pneumonia
# 1/1 [==============================] - 0s 62ms/step
# [[0.1063006]]
# Pneumonia
# 1/1 [==============================] - 0s 55ms/step
# [[0.10032069]]
# Pneumonia

# %%
modelres.evaluate(testing_dataset)
# Out:
# 39/39 [==============================] - 20s 521ms/step - loss: 0.6187 - accuracy: 0.6538
# [0.6186671853065491, 0.6538461446762085]

# %%
norm_path2 = 'chest_xray/test/PNEUMONIA'
arr = os.listdir(norm_path2)
# print(arr)
# random.shuffle(arr)
for i in arr[:10]:
#     print(i)
    img = cv2.imread(norm_path2+'/'+i)
    img = cv2.resize(img, (224,224))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis = 0)
    images = np.vstack([X])
    
    val2 = modelres.predict(images)
    print(val2)
    if val2 < 0.1:
        print("Normal")
    else:
        print("Pneumonia")
# Out:
# 1/1 [==============================] - 0s 53ms/step
# [[0.08238519]]
# Normal
# 1/1 [==============================] - 0s 58ms/step
# [[0.4348414]]
# Pneumonia
# 1/1 [==============================] - 0s 65ms/step
# [[0.2930554]]
# Pneumonia
# 1/1 [==============================] - 0s 59ms/step
# [[0.24323608]]
# Pneumonia
# 1/1 [==============================] - 0s 61ms/step
# [[0.21014804]]
# Pneumonia
# 1/1 [==============================] - 0s 64ms/step
# [[0.17946614]]
# Pneumonia
# 1/1 [==============================] - 0s 70ms/step
# [[0.35752273]]
# Pneumonia
# 1/1 [==============================] - 0s 62ms/step
# [[0.07867465]]
# Normal
# 1/1 [==============================] - 0s 92ms/step
# [[0.18347694]]
# Pneumonia
# 1/1 [==============================] - 0s 53ms/step
# [[0.20520738]]
# Pneumonia

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
# callback = ReduceLROnPlateau(monitor='val_loss', patience = 2, cooldown=0, verbose=1, factor=0.6, min_lr=0.000001)
resmodel = ResNet50(weights = 'imagenet',include_top=False, input_shape= (224,224,3))
for layers in resmodel.layers:
    layers.trainable = False
# print(resmodel.layers[18].name)
last_layer=resmodel.get_layer('conv3_block3_1_relu') #conv2_block1_out
last_output = last_layer.output

x=tf.keras.layers.Flatten()(last_output)
# x=tf.keras.layers.Dense(1024,activation='relu')(x)
# x=tf.keras.layers.Dropout(0.2)(x)
# x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dropout(0.5)(x)
x=tf.keras.layers.Dense(1,activation='sigmoid')(x)

modelresimg=tf.keras.Model(resmodel.input,x)

modelresimg.compile(loss = 'binary_crossentropy', 
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), #0.0001 and no 256 dense layer led to low loss
             metrics = ['accuracy']) #lr of 0.00005 with dense layers led to good training but same val accuracy
modelresimg.summary()
# Out:
# Model: "model_32"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_34 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_34[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  flatten_32 (Flatten)           (None, 100352)       0           ['conv3_block3_1_relu[0][0]']
#
#  dropout_35 (Dropout)           (None, 100352)       0           ['flatten_32[0][0]']
#
#  dense_39 (Dense)               (None, 1)            100353      ['dropout_35[0][0]']
#
# ==================================================================================================
# Total params: 1,061,889
# Trainable params: 100,353
# Non-trainable params: 961,536
# __________________________________________________________________________________________________

# %%
callback1 = ReduceLROnPlateau(monitor='val_loss', patience = 3, cooldown=0, verbose=1, factor=0.6, min_lr=0.00001)
callback2 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=9, restore_best_weights = True)
historyimagenet = modelresimg.fit(training_dataset, validation_data = validation_dataset, epochs = 30, steps_per_epoch = 2, callbacks = [callback1, callback2])
# Out:
# Epoch 1/30
# 2/2 [==============================] - 5s 2s/step - loss: 4.2688 - accuracy: 0.6562 - val_loss: 7.5941 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/30
# 2/2 [==============================] - 2s 1s/step - loss: 2.7552 - accuracy: 0.6562 - val_loss: 4.8053 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 3/30
# 2/2 [==============================] - 2s 1s/step - loss: 7.1261 - accuracy: 0.2188 - val_loss: 0.6730 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.9542 - accuracy: 0.7500 - val_loss: 6.3442 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/30
# 2/2 [==============================] - 2s 1s/step - loss: 3.5912 - accuracy: 0.7500 - val_loss: 8.7323 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 6/30
# 2/2 [==============================] - ETA: 0s - loss: 3.7634 - accuracy: 0.7500
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# 2/2 [==============================] - 2s 1s/step - loss: 3.7634 - accuracy: 0.7500 - val_loss: 6.6766 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 7/30
# 2/2 [==============================] - 2s 1s/step - loss: 2.5743 - accuracy: 0.7500 - val_loss: 3.5958 - val_accuracy: 0.5000 - lr: 6.0000e-04
# Epoch 8/30
# 2/2 [==============================] - 2s 1s/step - loss: 1.1769 - accuracy: 0.7500 - val_loss: 0.4083 - val_accuracy: 0.8125 - lr: 6.0000e-04
# Epoch 9/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.6791 - accuracy: 0.7188 - val_loss: 2.0633 - val_accuracy: 0.5000 - lr: 6.0000e-04
# Epoch 10/30
# 2/2 [==============================] - 2s 1s/step - loss: 3.1037 - accuracy: 0.3125 - val_loss: 0.7181 - val_accuracy: 0.6875 - lr: 6.0000e-04
# Epoch 11/30
# 2/2 [==============================] - ETA: 0s - loss: 0.6117 - accuracy: 0.7500
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# 2/2 [==============================] - 2s 1s/step - loss: 0.6117 - accuracy: 0.7500 - val_loss: 1.4475 - val_accuracy: 0.5000 - lr: 6.0000e-04
# Epoch 12/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.7143 - accuracy: 0.7500 - val_loss: 2.7084 - val_accuracy: 0.5000 - lr: 3.6000e-04
# Epoch 13/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.6659 - accuracy: 0.8750 - val_loss: 3.2505 - val_accuracy: 0.5000 - lr: 3.6000e-04
# Epoch 14/30
# 2/2 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.9375
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# 2/2 [==============================] - 2s 1s/step - loss: 0.4607 - accuracy: 0.9375 - val_loss: 3.2284 - val_accuracy: 0.5000 - lr: 3.6000e-04
# Epoch 15/30
# 2/2 [==============================] - 2s 1s/step - loss: 1.3859 - accuracy: 0.6875 - val_loss: 2.6215 - val_accuracy: 0.5000 - lr: 2.1600e-04
# Epoch 16/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.8753 - accuracy: 0.7812 - val_loss: 1.5641 - val_accuracy: 0.5625 - lr: 2.1600e-04
# Epoch 17/30
# 2/2 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.8750
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# 2/2 [==============================] - 2s 1s/step - loss: 0.2730 - accuracy: 0.8750 - val_loss: 0.7443 - val_accuracy: 0.8125 - lr: 2.1600e-04
# Epoch 18/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1040 - accuracy: 0.9375 - val_loss: 0.5091 - val_accuracy: 0.7500 - lr: 1.2960e-04
# Epoch 19/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1878 - accuracy: 0.9062 - val_loss: 0.3950 - val_accuracy: 0.8125 - lr: 1.2960e-04
# Epoch 20/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1255 - accuracy: 0.9375 - val_loss: 0.3681 - val_accuracy: 0.8125 - lr: 1.2960e-04
# Epoch 21/30
# 2/2 [==============================] - 2s 2s/step - loss: 0.4033 - accuracy: 0.8438 - val_loss: 0.3653 - val_accuracy: 0.8125 - lr: 1.2960e-04
# Epoch 22/30
# 2/2 [==============================] - 3s 2s/step - loss: 0.3065 - accuracy: 0.8750 - val_loss: 0.3683 - val_accuracy: 0.8125 - lr: 1.2960e-04
# Epoch 23/30
# 2/2 [==============================] - 2s 2s/step - loss: 0.3102 - accuracy: 0.9375 - val_loss: 0.4059 - val_accuracy: 0.8125 - lr: 1.2960e-04
# Epoch 24/30
# 2/2 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9375
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
# 2/2 [==============================] - 2s 2s/step - loss: 0.1453 - accuracy: 0.9375 - val_loss: 0.4899 - val_accuracy: 0.7500 - lr: 1.2960e-04
# Epoch 25/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1322 - accuracy: 0.9375 - val_loss: 0.5683 - val_accuracy: 0.8125 - lr: 7.7760e-05
# Epoch 26/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.0862 - accuracy: 0.9688 - val_loss: 0.6428 - val_accuracy: 0.8125 - lr: 7.7760e-05
# Epoch 27/30
# 2/2 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9375
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
# 2/2 [==============================] - 2s 1s/step - loss: 0.1679 - accuracy: 0.9375 - val_loss: 0.7061 - val_accuracy: 0.8125 - lr: 7.7760e-05
# Epoch 28/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2653 - accuracy: 0.8750 - val_loss: 0.7374 - val_accuracy: 0.8125 - lr: 4.6656e-05
# Epoch 29/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2415 - accuracy: 0.9375 - val_loss: 0.7593 - val_accuracy: 0.8125 - lr: 4.6656e-05
# Epoch 30/30
# 2/2 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.8750
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
# 2/2 [==============================] - 2s 1s/step - loss: 0.3087 - accuracy: 0.8750 - val_loss: 0.7615 - val_accuracy: 0.8125 - lr: 4.6656e-05

# %%
acc = historyimagenet.history['accuracy']
val_acc = historyimagenet.history['val_accuracy']



loss = historyimagenet.history['loss']
val_loss = historyimagenet.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
norm_path = 'chest_xray/test/NORMAL'
arr = os.listdir(norm_path)
# print(arr)
# random.shuffle(arr)
for i in arr[:10]:
#     print(i)
    img = cv2.imread(norm_path+'/'+i)
    img = cv2.resize(img, (224,224))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis = 0)
    images = np.vstack([X])
    
    val = modelresimg.predict(images)
    print(val)
#     if val == 0:
#         print("Normal")
#     else:
#         print("Pneumonia")
# Out:
# 1/1 [==============================] - 0s 346ms/step
# [[0.98362243]]
# 1/1 [==============================] - 0s 61ms/step
# [[0.98239696]]
# 1/1 [==============================] - 0s 58ms/step
# [[0.9974814]]
# 1/1 [==============================] - 0s 136ms/step
# [[0.99975175]]
# 1/1 [==============================] - 0s 58ms/step
# [[0.9983274]]
# 1/1 [==============================] - 0s 61ms/step
# [[0.98387027]]
# 1/1 [==============================] - 0s 57ms/step
# [[0.9921078]]
# 1/1 [==============================] - 0s 58ms/step
# [[0.9956835]]
# 1/1 [==============================] - 0s 75ms/step
# [[0.99897337]]
# 1/1 [==============================] - 0s 55ms/step
# [[0.9883976]]

# %%
modelresimg.evaluate(testing_dataset)
# Out:
# 39/39 [==============================] - 24s 609ms/step - loss: 0.8300 - accuracy: 0.7099
# [0.8299657106399536, 0.7099359035491943]
